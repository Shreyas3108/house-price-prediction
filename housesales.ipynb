# %%
# Import necessary libraries
import numpy as np  # For numerical operations
import pandas as pd  # For data manipulation and analysis
import matplotlib.pyplot as plt  # For creating plots
import seaborn as sns  # For enhanced visualization
import mpl_toolkits  # Additional toolkit for matplotlib
import warnings  # For suppressing unnecessary warnings

# Suppress warnings
warnings.filterwarnings("ignore")

# Magic command to display plots inline in Jupyter Notebook
# %matplotlib inline

# %%
# Read the dataset from a CSV file into a pandas DataFrame
data = pd.read_csv("kc_house_data.csv")

# %%
# View the first few rows of our data
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
# Generate descriptive statistics of the dataset
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
# Plotting the count of bedrooms using a bar plot
data['bedrooms'].value_counts().plot(kind='bar')

# Adding title and axis labels to the plot
plt.title('Number of Bedrooms')
plt.xlabel('Bedrooms')
plt.ylabel('Count')

# Removing the top and right spines of the plot for a cleaner appearance
sns.despine()

# %%
# Set the size of the figure for the joint plot
plt.figure(figsize=(10, 10))

# Create a joint plot comparing latitude and longitude
sns.jointplot(x=data.lat.values, y=data.long.values, size=10)

# Add labels to the x-axis and y-axis
plt.ylabel('Longitude', fontsize=12)
plt.xlabel('Latitude', fontsize=12)

# Display the plot
plt.show()

# Create a new figure (plt1 is not defined)
# plt1 = plt()  # This line is unnecessary and would cause an error

# Remove spines for aesthetic purposes
sns.despine()

# %%
# Create a scatter plot of price vs. square feet of living space
plt.scatter(data.price, data.sqft_living)

# Add title to the plot
plt.title("Price vs Square Feet")

# Display the plot
plt.show()

# %%
# Create a scatter plot of price vs. longitude
plt.scatter(data.price, data.long)

# Add title to the plot
plt.title("Price vs Location of the Area")

# Display the plot
plt.show()

# %%
# Create a scatter plot of price vs. latitude
plt.scatter(data.price, data.lat)

# Add labels to the x-axis and y-axis
plt.xlabel("Price")
plt.ylabel('Latitude')

# Add title to the plot
plt.title("Latitude vs Price")

# Display the plot
plt.show()

# %%
# Create a scatter plot of bedrooms vs. price
plt.scatter(data.bedrooms, data.price)

# Add title to the plot
plt.title("Bedrooms and Price")

# Add labels to the x-axis and y-axis
plt.xlabel("Bedrooms")
plt.ylabel("Price")

# Display the plot
plt.show()

# Remove spines for aesthetic purposes
sns.despine()

# %%
# Create a scatter plot of total square footage (living area + basement) vs. price
plt.scatter((data['sqft_living'] + data['sqft_basement']), data['price'])

# Add title to the plot
plt.title("Total Square Footage vs. Price")

# Add labels to the x-axis and y-axis
plt.xlabel("Total Square Footage")
plt.ylabel("Price")

# Display the plot
plt.show()

# %%
# Create a scatter plot of waterfront vs. price
plt.scatter(data.waterfront, data.price)

# Add title to the plot
plt.title("Waterfront vs Price (0 = No Waterfront)")

# Add labels to the x-axis and y-axis
plt.xlabel("Waterfront (0 = No, 1 = Yes)")
plt.ylabel("Price")

# Display the plot
plt.show()

# %%
# Create a new DataFrame for training by dropping columns 'id' and 'price'
train1 = data.drop(['id', 'price'], axis=1)

# %%
train1.head()
# Out:
#               date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  20141013T000000         3       1.00         1180      5650     1.0
# 1  20141209T000000         3       2.25         2570      7242     2.0
# 2  20150225T000000         2       1.00          770     10000     1.0
# 3  20141209T000000         4       3.00         1960      5000     1.0
# 4  20150218T000000         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
# Plot the count of different floor types using a bar plot
data.floors.value_counts().plot(kind='bar')

# Add title to the plot
plt.title('Count of Different Floor Types')

# Add labels to the x-axis and y-axis
plt.xlabel('Floor Types')
plt.ylabel('Count')

# Display the plot
plt.show()

# %%
# Create a scatter plot of floors vs. price
plt.scatter(data.floors, data.price)

# Add title to the plot
plt.title("Floors vs Price")

# Add labels to the x-axis and y-axis
plt.xlabel("Floors")
plt.ylabel("Price")

# Display the plot
plt.show()

# %%
# Create a scatter plot of condition vs. price
plt.scatter(data.condition, data.price)

# Add title to the plot
plt.title("Condition vs Price")

# Add labels to the x-axis and y-axis
plt.xlabel("Condition")
plt.ylabel("Price")

# Display the plot
plt.show()

# %%
# Create a scatter plot of zipcode vs. price
plt.scatter(data.zipcode, data.price)

# Add title to the plot
plt.title("Price vs Zipcode")

# Add labels to the x-axis and y-axis
plt.xlabel("Zipcode")
plt.ylabel("Price")

# Display the plot
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
# Instantiate LinearRegression model
reg = LinearRegression()

# %%
# Extract the target variable 'price' into labels
labels = data['price']

# Convert the 'date' column to binary (1 for 2014, 0 for others)
conv_dates = [1 if values == 2014 else 0 for values in data.date]
data['date'] = conv_dates

# Create a new DataFrame for training by dropping columns 'id' and 'price'
train1 = data.drop(['id', 'price'], axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(train1, labels, test_size=0.10, random_state=2)

# %%
# Fit the LinearRegression model to the training data
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Calculate the coefficient of determination (R²) for the test data
score = reg.score(x_test, y_test)

# Print the R² score
print("R² score:", score)
# Out:
# R² score: 0.7320342760357534

# %%
from sklearn import ensemble

# Initialize Gradient Boosting Regressor with specified parameters
clf = ensemble.GradientBoostingRegressor(n_estimators=400, 
                                         max_depth=5, 
                                         min_samples_split=2,
                                         learning_rate=0.1)

# %%
# Fit the Gradient Boosting Regressor to the training data
clf.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=5, n_estimators=400)

# %%
# Calculate the coefficient of determination (R²) for the test data
score = clf.score(x_test, y_test)

# Print the R² score
print("R² score:", score)
# Out:
# R² score: 0.9190659088394894

# %%
# Define parameters
params = {
    'n_estimators': 400  # Example value for the number of estimators
}

# Create a NumPy array filled with zeros to store training scores
t_sc = np.zeros((params['n_estimators']), dtype=np.float64)

# %%
# Generate predictions on the test data
y_pred = reg.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

# Iterate through each boosting iteration and compute the training scores
for i, y_pred in enumerate(clf.staged_predict(x_test)):
    # Compute the mean squared error (MSE) between true labels (y_test) and predictions (y_pred) for the current iteration
    t_sc[i] = mean_squared_error(y_test, y_pred)

# %%
# Create an array containing numbers from 1 to n_estimators
testsc = np.arange(params['n_estimators']) + 1

# %%
# Set the figure size
plt.figure(figsize=(12, 6))

# Create a subplot with 1 row and 2 columns, and set the current subplot to the first one
plt.subplot(1, 2, 1)

# Plot the training scores for each boosting iteration
plt.plot(testsc, clf.train_score_, 'b-', label='Set dev train')

# Plot the computed training scores for each boosting iteration
plt.plot(testsc, t_sc, 'r-', label='set dev test')

# Add labels to the x-axis and y-axis
plt.xlabel('Boosting Iterations')
plt.ylabel('Training Scores')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA

# %%
pca = PCA()

# %%
# Fit PCA to the scaled training data and transform it
transformed_data = pca.fit_transform(scale(train1))

# %%
# Print the transformed data
print(transformed_data)
# Out:
# [[-2.64785461e+00 -4.54699955e-02 -3.16665762e-01 ... -7.94687728e-02
#    3.11022171e-16  0.00000000e+00]
#  [-2.34485164e-01  1.68297114e+00 -7.61521725e-01 ...  9.81487761e-01
#    1.37521324e-14 -0.00000000e+00]
#  [-2.57007792e+00 -6.14344122e-01  3.49292423e-01 ... -1.38570764e-01
#   -2.07283451e-16  0.00000000e+00]
#  ...
#  [-2.41985641e+00 -1.10027662e+00 -1.46293798e+00 ...  9.66785881e-01
#   -1.06563882e-16 -0.00000000e+00]
#  [ 3.32183025e-01 -1.88043103e+00 -1.04412760e+00 ... -3.97449542e-01
#    1.13280908e-16  0.00000000e+00]
#  [-2.43180432e+00 -1.08505981e+00 -1.47248379e+00 ...  9.53674385e-01
#   -9.02929634e-17 -0.00000000e+00]]
